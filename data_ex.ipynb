# %%
pip install cfbd --upgrade
# Out:
# ...
#
# ...

# %%
import requests
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cfbd

# %%
with open('keys.json') as fi:
    credentials = json.load(fi)

# %%
api_key = credentials['api_key']

# %%
configuration = cfbd.Configuration()
configuration.api_key['Authorization'] = api_key
configuration.api_key_prefix['Authorization'] = 'Bearer'

api_config = cfbd.ApiClient(configuration)

# %%
teams_api = cfbd.TeamsApi(api_config)

# %%
teams_api.get_fbs_teams()
# Out:
# [{'abbreviation': 'AFA',
#   'alt_color': '#ffffff',
#   'alt_name_1': None,
#   'alt_name_2': None,
#   'alt_name_3': None,
#   'classification': None,
#   'color': '#004a7b',
#   'conference': 'Mountain West',
#   'division': 'Mountain',
#   'id': 2005,
#   'location': {'capacity': 46692.0,
#                'city': 'Colorado Springs',
#                'country_code': 'US',
#                'dome': False,
#                'elevation': 2024.875732,
#                'grass': False,
#                'latitude': 38.9969701,
#                'longitude': -104.8436165,
#                'name': 'Falcon Stadium',
#                'state': 'CO',
#                'timezone': 'America/Denver',
#                'venue_id': 3713,
#                'year_constructed': 1962.0,
#                'zip': '80840'},
#   'logos': ['http://a.espncdn.com/i/teamlogos/ncaa/500/2005.png',
#             'http://a.espncdn.com/i/teamlogos/ncaa/500-dark/2005.png'],
#   'mascot': 'Falcons',
# ...

# %%
betting_api = cfbd.BettingApi(api_config)
betting_2022 = betting_api.get_lines(year=2022)

# %%
betting_2022_df = pd.DataFrame.from_records([g.to_dict() for g in betting_2022])
betting_2022_df.head()
# Out:
#           id  season  week season_type                start_date  \
# 0  401411101    2022     1     regular  2022-09-06T00:00:00.000Z
# 1  401431455    2022     9     regular  2022-10-29T20:00:00.000Z
# 2  401431558    2022     9     regular  2022-10-29T20:00:00.000Z
# 3  401431858    2022     9     regular  2022-10-29T21:00:00.000Z
# 4  401431909    2022     9     regular  2022-10-29T20:00:00.000Z
#
#             home_team         home_conference  home_score  \
# 0        Georgia Tech                     ACC        10.0
# 1             Harding          Great American        28.0
# 2              Tiffin  Great Midwest Athletic        48.0
# 3        West Florida              Gulf South        36.0
# 4  Eastern New Mexico               Lone Star        21.0
#
#                                   away_team         away_conference  \
# 0                                   Clemson                     ACC
# 1               Northwestern Oklahoma State          Great American
# ...

# %%
try:
        betting_2022_df.append(pd.json_normalize(betting_2022_df['lines'][1]))
except IndexError:
        betting_2022_df.append('null')
# Out:
# C:\Users\antho\AppData\Local\Temp\ipykernel_19540\3736550180.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   betting_2022_df.append(pd.json_normalize(betting_2022_df['lines'][1]))

# %%
betting_2022_df
# Out:
#              id  season  week season_type                start_date  \
# 0     401411101    2022     1     regular  2022-09-06T00:00:00.000Z
# 1     401431455    2022     9     regular  2022-10-29T20:00:00.000Z
# 2     401431558    2022     9     regular  2022-10-29T20:00:00.000Z
# 3     401431858    2022     9     regular  2022-10-29T21:00:00.000Z
# 4     401431909    2022     9     regular  2022-10-29T20:00:00.000Z
# ...         ...     ...   ...         ...                       ...
# 3652  401432368    2022     8     regular  2022-10-22T19:00:00.000Z
# 3653  401432963    2022     8     regular  2022-10-22T19:00:00.000Z
# 3654  401433018    2022     8     regular  2022-10-22T19:00:00.000Z
# 3655  401432994    2022     8     regular  2022-10-22T19:30:00.000Z
# 3656  401431862    2022     8     regular  2022-10-22T21:00:00.000Z
#
#                home_team              home_conference  home_score  \
# 0           Georgia Tech                          ACC        10.0
# ...

# %%
betting_2022_df['lines'][0]
# Out:
# [{'provider': 'Bovada',
#   'spread': 24.5,
#   'formatted_spread': 'Clemson -24.5',
#   'spread_open': 21.0,
#   'over_under': 51.5,
#   'over_under_open': 51.0,
#   'home_moneyline': 950.0,
#   'away_moneyline': -2000.0},
#  {'provider': 'William Hill (New Jersey)',
#   'spread': 24.0,
#   'formatted_spread': 'Clemson -24',
#   'spread_open': None,
#   'over_under': 51.5,
#   'over_under_open': None,
#   'home_moneyline': None,
#   'away_moneyline': None},
#  {'provider': 'consensus',
#   'spread': 24.5,
#   'formatted_spread': 'Clemson -24.5',
#   'spread_open': None,
#   'over_under': 51.5,
#   'over_under_open': None,
#   'home_moneyline': None,
#   'away_moneyline': None},
#  {'provider': 'teamrankings',
#   'spread': 24.5,
#   'formatted_spread': 'Clemson -24.5',
#   'spread_open': None,
#   'over_under': 51.0,
#   'over_under_open': None,
#   'home_moneyline': None,
#   'away_moneyline': None}]

# %%
betting_2022_df['lines'][0][2]
# Out:
# {'provider': 'consensus',
#  'spread': 24.5,
#  'formatted_spread': 'Clemson -24.5',
#  'spread_open': None,
#  'over_under': 51.5,
#  'over_under_open': None,
#  'home_moneyline': None,
#  'away_moneyline': None}

# %%
betting_2022_df = pd.concat([betting_2022_df, betting_2022_df['lines'].apply(pd.Series)], axis=1)
# Out:
# C:\Users\antho\AppData\Local\Temp\ipykernel_19540\1868473151.py:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   betting_2022_df = pd.concat([betting_2022_df, betting_2022_df['lines'].apply(pd.Series)], axis=1)

# %%
betting_2022_df = betting_2022_df.drop('lines', axis=1)

# %%
pd.json_normalize(betting_2022_df[0])
# Out:
#      provider  spread formatted_spread  spread_open  over_under  \
# 0      Bovada    24.5    Clemson -24.5         21.0        51.5
# 1         NaN     NaN              NaN          NaN         NaN
# 2         NaN     NaN              NaN          NaN         NaN
# 3         NaN     NaN              NaN          NaN         NaN
# 4         NaN     NaN              NaN          NaN         NaN
# ...       ...     ...              ...          ...         ...
# 3652      NaN     NaN              NaN          NaN         NaN
# 3653      NaN     NaN              NaN          NaN         NaN
# 3654      NaN     NaN              NaN          NaN         NaN
# 3655      NaN     NaN              NaN          NaN         NaN
# 3656      NaN     NaN              NaN          NaN         NaN
#
#       over_under_open  home_moneyline  away_moneyline
# 0                51.0           950.0         -2000.0
# 1                 NaN             NaN             NaN
# ...
